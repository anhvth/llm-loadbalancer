# %%
from speedy_utils import *
import pandas as pd

# %%
items = load_by_ext('/home/anhvth8/.cache/llm-proxy/training-data/2026-04-1*')
# Out:
# Multi-worker [spawn: 16p]:  50%|█████████████████████████████████████████████████████                                                     | 1/2 [00:00<00:00,  2.83it/s, ok=1, err=0, proc=1/2, start=2, active=1]
# Reading JSONL:  38%|###8      | 33.6M/87.9M [00:00<00:00, 168MB/s]
# Multi-worker [spawn: 16p]:  50%|█████████████████████████████████████████████████████                                                     | 1/2 [00:00<00:00,  2.83it/s, ok=1, err=0, proc=1/2, start=2, active=1]
# Reading JSONL:  76%|#######6  | 67.1M/87.9M [00:00<00:00, 166MB/s]
# Multi-worker [spawn: 16p]:  50%|█████████████████████████████████████████████████████                                                     | 1/2 [00:01<00:00,  2.83it/s, ok=1, err=0, proc=1/2, start=2, active=1]
# Reading JSONL: 100%|##########| 87.9M/87.9M [00:00<00:00, 163MB/s]
# ...

# %%
len(items)

# %%
items = pd.DataFrame(items)
